# %% [markdown]
# Colab for [Ultimate RVC](https://github.com/JackismyShephard/ultimate-rvc)
#
# This Colab notebook will **help** you if you don’t have a GPU or if your PC isn’t very powerful.
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.
#
# NOTE: If Ultimate RVC is running too slowly with the default sharing method (gradio), consider instead selecting "ngrok" as sharing method.
# This method requires supplying an access token, which you can find on [ngrok](https://ngrok.com/) after creating a personal account.
# The ngrok link output in the final cell will lead you to a new site which will redirect you to Ultimate RVC.

# %%
# @title 0: Initialize notebook
# %pip install ipython-autotime pyngrok
# %load_ext autotime

import codecs
import os
import time
from pathlib import Path
from urllib import request

import ipywidgets as widgets
from IPython.display import clear_output
from IPython.display import display as i_display
from pyngrok import ngrok

clear_output()
# Out:
# time: 95.1 ms (started: 2025-11-01 06:16:32 +00:00)

# %%
# @title 1: Clone repository
cloneing = codecs.decode(
    "uggcf://tvguho.pbz/WnpxvfzlFurcuneq/hygvzngr-eip.tvg",
    "rot_13",
)

# !git clone $cloneing HRVC
# %cd /content/HRVC
clear_output()
# Out:
# time: 1.52 s (started: 2025-11-01 06:16:42 +00:00)

# %%
# @title 2: Install dependencies

light = codecs.decode("uggcf://nfgeny.fu/hi/0.6.3/vafgnyy.fu", "rot_13")
inits = codecs.decode("./fep/hygvzngr_eip/pber/znva.cl", "rot_13")
prerelease = "--prerelease if-necessary-or-explicit"

# !apt install -y python3-dev unzip
# !curl -LsSf $light | sh

os.environ["URVC_CONSOLE_LOG_LEVEL"] = "WARNING"
# !uv run -q $prerelease $inits
# !uv add $prerelease matplotlib-inline==0.1.7
clear_output()
# Out:
# time: 3min 57s (started: 2025-11-01 06:17:02 +00:00)

# %%
# @title 3: Run Ultimate RVC
# @markdown  #### Choose a sharing method:

method = "gradio"  # @param ["gradio",  "ngrok", "cloudflared","localtunnel"]
ngrok_token = "2wgKwOVlRo7TvGcrrG07RtYEItU_64sUmVkhhaTefNfubozvj"  # @param {type:"string"}
runpice = codecs.decode("./fep/hygvzngr_eip/jro/znva.cl", "rot_13")

if method == "gradio":
    # !uv run $prerelease $runpice --share
elif method == "ngrok":
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: {tunnel.public_url}")
        # !uv run $prerelease $runpice --listen-port 6969
    except Exception as e:  # noqa: BLE001
        print(f"Error starting ngrok: {e}")
elif method == "cloudflared":
    # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    clear_output()
    # !rm -rf nohup.out
    # !nohup cloudflared tunnel --url localhost:6969 &
    clear_output()
    time.sleep(10)
    cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
    print(f"URVC Public URL: {cloudflare_url}")
    # !uv run $prerelease $runpice --listen-port 6969
elif method == "localtunnel":
    # !npm install -g localtunnel &>/dev/null
    Path("url.txt").open("w", encoding="utf-8").close()
    # !lt --port 6969 >> url.txt 2>&1 &
    time.sleep(2)
    endpoint_ip = (
        request.urlopen("https://ipv4.icanhazip.com").read().decode("utf8").strip("\n")
    )
    tunnel_url = (
        Path("url.txt").read_text(encoding="utf-8").replace("your url is: ", "")
    )
    print(f"Share Link: {tunnel_url}")
    password_endpoint_widget = widgets.Text(
        value=endpoint_ip,
        description="Password IP:",
        disabled=True,
    )
    i_display(password_endpoint_widget)
    # !uv run $prerelease $runpice --listen-port 6969 --share true
# Out:
# Bytecode compiled 18302 files in 2.08s
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://4358607b88aa782047.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 100% 1/1 [00:20<00:00, 20.16s/it]
# [~] Extracting pitch features...
# 100% 10/10 [00:02<00:00,  4.98it/s]
# [~] Extracting audio embeddings...
# 100% 10/10 [00:00<00:00, 14.78it/s]
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025-11-01 06:26:53 - ERROR - ultimate_rvc.rvc.train.train - Not enough data in the training set. Perhaps you forgot to slice the audio files in preprocess?
# [rank0]:[W1101 06:26:54.234170903 ProcessGroupNCCL.cpp:1524] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# 2025-11-01 06:26:54 - WARNING - ultimate_rvc.rvc.train.train - Process running on device 0 exited with code 1.
# Traceback (most recent call last):
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 70, in _wrapped_fn
#     res = fn(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/train/train.py", line 299, in run_training
#     train_main(
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 269, in main
#     start()
#   File "/content/HRVC/src/ultimate_rvc/rvc/train/train.py", line 254, in start
#     raise RuntimeError(err_msg)
# RuntimeError: One or more training processes failed. See the logs or console for details.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2136, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1662, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 883, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 77, in _wrapped_fn
#     raise gr.Error(str(e)) from e
# gradio.exceptions.Error: 'One or more training processes failed. See the logs or console for details.'
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# My model | epoch=1 | time=06:28:26 | speed=0:00:26 | best avg-gen-loss=71.509 (epoch 1) | overtrain countdown: g=50,d=100 | avg-gen-loss=71.509 | avg-disc-loss=2.001
# My model | epoch=2 | time=06:28:30 | speed=0:00:03 | best avg-gen-loss=46.540 (epoch 2) | overtrain countdown: g=50,d=100 | avg-gen-loss=46.540 | avg-disc-loss=1.375
# My model | epoch=3 | time=06:28:33 | speed=0:00:03 | best avg-gen-loss=40.999 (epoch 3) | overtrain countdown: g=50,d=100 | avg-gen-loss=40.999 | avg-disc-loss=1.224
# My model | epoch=4 | time=06:28:37 | speed=0:00:03 | best avg-gen-loss=36.106 (epoch 4) | overtrain countdown: g=50,d=100 | avg-gen-loss=36.106 | avg-disc-loss=1.175
# My model | epoch=5 | time=06:28:41 | speed=0:00:03 | best avg-gen-loss=34.099 (epoch 5) | overtrain countdown: g=50,d=99 | avg-gen-loss=34.099 | avg-disc-loss=1.218
# My model | epoch=6 | time=06:28:46 | speed=0:00:04 | best avg-gen-loss=32.815 (epoch 6) | overtrain countdown: g=50,d=98 | avg-gen-loss=32.815 | avg-disc-loss=1.196
# My model | epoch=7 | time=06:28:50 | speed=0:00:03 | best avg-gen-loss=31.860 (epoch 7) | overtrain countdown: g=50,d=100 | avg-gen-loss=31.860 | avg-disc-loss=1.153
# My model | epoch=8 | time=06:28:54 | speed=0:00:03 | best avg-gen-loss=30.914 (epoch 8) | overtrain countdown: g=50,d=100 | avg-gen-loss=30.914 | avg-disc-loss=1.137
# My model | epoch=9 | time=06:28:58 | speed=0:00:03 | best avg-gen-loss=30.283 (epoch 9) | overtrain countdown: g=50,d=100 | avg-gen-loss=30.283 | avg-disc-loss=1.127
# My model | epoch=10 | time=06:29:02 | speed=0:00:03 | best avg-gen-loss=30.212 (epoch 10) | overtrain countdown: g=50,d=100 | avg-gen-loss=30.212 | avg-disc-loss=1.074
# My model | epoch=11 | time=06:29:29 | speed=0:00:03 | best avg-gen-loss=29.862 (epoch 11) | overtrain countdown: g=50,d=100 | avg-gen-loss=29.862 | avg-disc-loss=1.033
# My model | epoch=12 | time=06:29:34 | speed=0:00:04 | best avg-gen-loss=28.803 (epoch 12) | overtrain countdown: g=50,d=99 | avg-gen-loss=28.803 | avg-disc-loss=1.069
# My model | epoch=13 | time=06:29:38 | speed=0:00:04 | best avg-gen-loss=27.770 (epoch 13) | overtrain countdown: g=50,d=98 | avg-gen-loss=27.770 | avg-disc-loss=1.209
# My model | epoch=14 | time=06:29:42 | speed=0:00:03 | best avg-gen-loss=27.178 (epoch 14) | overtrain countdown: g=50,d=97 | avg-gen-loss=27.178 | avg-disc-loss=1.216
# My model | epoch=15 | time=06:29:47 | speed=0:00:04 | best avg-gen-loss=26.280 (epoch 15) | overtrain countdown: g=50,d=96 | avg-gen-loss=26.280 | avg-disc-loss=1.124
# My model | epoch=16 | time=06:29:51 | speed=0:00:04 | best avg-gen-loss=26.280 (epoch 15) | overtrain countdown: g=49,d=100 | avg-gen-loss=26.786 | avg-disc-loss=0.946
# My model | epoch=17 | time=06:29:55 | speed=0:00:04 | best avg-gen-loss=26.280 (epoch 15) | overtrain countdown: g=48,d=100 | avg-gen-loss=26.698 | avg-disc-loss=0.865
# My model | epoch=18 | time=06:30:00 | speed=0:00:04 | best avg-gen-loss=25.125 (epoch 18) | overtrain countdown: g=50,d=99 | avg-gen-loss=25.125 | avg-disc-loss=0.971
# My model | epoch=19 | time=06:30:04 | speed=0:00:04 | best avg-gen-loss=25.125 (epoch 18) | overtrain countdown: g=49,d=98 | avg-gen-loss=26.735 | avg-disc-loss=1.833
# My model | epoch=20 | time=06:30:08 | speed=0:00:04 | best avg-gen-loss=24.821 (epoch 20) | overtrain countdown: g=50,d=97 | avg-gen-loss=24.821 | avg-disc-loss=1.694
# My model | epoch=21 | time=06:30:18 | speed=0:00:04 | best avg-gen-loss=24.821 (epoch 20) | overtrain countdown: g=49,d=96 | avg-gen-loss=25.473 | avg-disc-loss=1.409
# My model | epoch=22 | time=06:30:22 | speed=0:00:03 | best avg-gen-loss=23.125 (epoch 22) | overtrain countdown: g=50,d=95 | avg-gen-loss=23.125 | avg-disc-loss=1.249
# My model | epoch=23 | time=06:30:26 | speed=0:00:04 | best avg-gen-loss=22.239 (epoch 23) | overtrain countdown: g=50,d=94 | avg-gen-loss=22.239 | avg-disc-loss=1.165
# My model | epoch=24 | time=06:30:31 | speed=0:00:03 | best avg-gen-loss=22.239 (epoch 23) | overtrain countdown: g=49,d=93 | avg-gen-loss=22.313 | avg-disc-loss=1.129
# My model | epoch=25 | time=06:30:35 | speed=0:00:04 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=50,d=92 | avg-gen-loss=21.483 | avg-disc-loss=1.121
# My model | epoch=26 | time=06:30:39 | speed=0:00:04 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=49,d=91 | avg-gen-loss=22.206 | avg-disc-loss=1.166
# My model | epoch=27 | time=06:30:43 | speed=0:00:04 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=48,d=90 | avg-gen-loss=22.005 | avg-disc-loss=1.157
# My model | epoch=28 | time=06:30:47 | speed=0:00:03 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=47,d=89 | avg-gen-loss=23.373 | avg-disc-loss=1.093
# My model | epoch=29 | time=06:30:52 | speed=0:00:04 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=46,d=88 | avg-gen-loss=21.764 | avg-disc-loss=1.030
# My model | epoch=30 | time=06:30:56 | speed=0:00:04 | best avg-gen-loss=21.483 (epoch 25) | overtrain countdown: g=45,d=87 | avg-gen-loss=22.190 | avg-disc-loss=0.975
# My model | epoch=31 | time=06:31:06 | speed=0:00:04 | best avg-gen-loss=21.434 (epoch 31) | overtrain countdown: g=50,d=86 | avg-gen-loss=21.434 | avg-disc-loss=0.932
# My model | epoch=32 | time=06:31:10 | speed=0:00:04 | best avg-gen-loss=21.434 (epoch 31) | overtrain countdown: g=49,d=85 | avg-gen-loss=22.315 | avg-disc-loss=0.917
# My model | epoch=33 | time=06:31:14 | speed=0:00:03 | best avg-gen-loss=20.133 (epoch 33) | overtrain countdown: g=50,d=84 | avg-gen-loss=20.133 | avg-disc-loss=1.031
# My model | epoch=34 | time=06:31:18 | speed=0:00:04 | best avg-gen-loss=19.070 (epoch 34) | overtrain countdown: g=50,d=83 | avg-gen-loss=19.070 | avg-disc-loss=1.222
# My model | epoch=35 | time=06:31:23 | speed=0:00:04 | best avg-gen-loss=18.344 (epoch 35) | overtrain countdown: g=50,d=82 | avg-gen-loss=18.344 | avg-disc-loss=1.101
# My model | epoch=36 | time=06:31:27 | speed=0:00:04 | best avg-gen-loss=18.256 (epoch 36) | overtrain countdown: g=50,d=81 | avg-gen-loss=18.256 | avg-disc-loss=1.054
# My model | epoch=37 | time=06:31:31 | speed=0:00:04 | best avg-gen-loss=18.256 (epoch 36) | overtrain countdown: g=49,d=80 | avg-gen-loss=18.802 | avg-disc-loss=1.217
# My model | epoch=38 | time=06:31:36 | speed=0:00:04 | best avg-gen-loss=18.256 (epoch 36) | overtrain countdown: g=48,d=79 | avg-gen-loss=19.546 | avg-disc-loss=1.268
# My model | epoch=39 | time=06:31:40 | speed=0:00:03 | best avg-gen-loss=17.357 (epoch 39) | overtrain countdown: g=50,d=78 | avg-gen-loss=17.357 | avg-disc-loss=1.176
# My model | epoch=40 | time=06:31:44 | speed=0:00:04 | best avg-gen-loss=17.357 (epoch 39) | overtrain countdown: g=49,d=77 | avg-gen-loss=19.301 | avg-disc-loss=0.906
# My model | epoch=41 | time=06:31:54 | speed=0:00:03 | best avg-gen-loss=17.357 (epoch 39) | overtrain countdown: g=48,d=100 | avg-gen-loss=18.956 | avg-disc-loss=0.791
# My model | epoch=42 | time=06:31:58 | speed=0:00:04 | best avg-gen-loss=17.357 (epoch 39) | overtrain countdown: g=47,d=99 | avg-gen-loss=17.777 | avg-disc-loss=0.880
# My model | epoch=43 | time=06:32:02 | speed=0:00:03 | best avg-gen-loss=17.357 (epoch 39) | overtrain countdown: g=46,d=98 | avg-gen-loss=17.541 | avg-disc-loss=1.061
# My model | epoch=44 | time=06:32:06 | speed=0:00:03 | best avg-gen-loss=17.114 (epoch 44) | overtrain countdown: g=50,d=97 | avg-gen-loss=17.114 | avg-disc-loss=1.373
# My model | epoch=45 | time=06:32:10 | speed=0:00:04 | best avg-gen-loss=16.472 (epoch 45) | overtrain countdown: g=50,d=96 | avg-gen-loss=16.472 | avg-disc-loss=1.093
# My model | epoch=46 | time=06:32:15 | speed=0:00:04 | best avg-gen-loss=16.472 (epoch 45) | overtrain countdown: g=49,d=95 | avg-gen-loss=21.036 | avg-disc-loss=0.889
# My model | epoch=47 | time=06:32:19 | speed=0:00:04 | best avg-gen-loss=16.472 (epoch 45) | overtrain countdown: g=48,d=94 | avg-gen-loss=20.293 | avg-disc-loss=1.057
# My model | epoch=48 | time=06:32:23 | speed=0:00:04 | best avg-gen-loss=16.472 (epoch 45) | overtrain countdown: g=47,d=93 | avg-gen-loss=18.390 | avg-disc-loss=1.193
# My model | epoch=49 | time=06:32:27 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=50,d=92 | avg-gen-loss=16.296 | avg-disc-loss=1.233
# My model | epoch=50 | time=06:32:32 | speed=0:00:03 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=49,d=91 | avg-gen-loss=17.911 | avg-disc-loss=1.414
# My model | epoch=51 | time=06:32:41 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=48,d=90 | avg-gen-loss=17.911 | avg-disc-loss=1.348
# My model | epoch=52 | time=06:32:45 | speed=0:00:03 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=47,d=89 | avg-gen-loss=18.288 | avg-disc-loss=1.267
# My model | epoch=53 | time=06:32:50 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=46,d=88 | avg-gen-loss=17.907 | avg-disc-loss=1.191
# My model | epoch=54 | time=06:32:54 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=45,d=87 | avg-gen-loss=16.478 | avg-disc-loss=1.139
# My model | epoch=55 | time=06:32:58 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=44,d=86 | avg-gen-loss=20.514 | avg-disc-loss=1.111
# My model | epoch=56 | time=06:33:02 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=43,d=85 | avg-gen-loss=19.922 | avg-disc-loss=1.086
# My model | epoch=57 | time=06:33:06 | speed=0:00:04 | best avg-gen-loss=16.296 (epoch 49) | overtrain countdown: g=42,d=84 | avg-gen-loss=17.018 | avg-disc-loss=1.111
# My model | epoch=58 | time=06:33:10 | speed=0:00:03 | best avg-gen-loss=16.155 (epoch 58) | overtrain countdown: g=50,d=83 | avg-gen-loss=16.155 | avg-disc-loss=1.093
# My model | epoch=59 | time=06:33:15 | speed=0:00:04 | best avg-gen-loss=16.155 (epoch 58) | overtrain countdown: g=49,d=82 | avg-gen-loss=16.564 | avg-disc-loss=1.087
# My model | epoch=60 | time=06:33:19 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=50,d=81 | avg-gen-loss=15.434 | avg-disc-loss=1.067
# My model | epoch=61 | time=06:33:29 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=49,d=80 | avg-gen-loss=18.826 | avg-disc-loss=0.962
# My model | epoch=62 | time=06:33:33 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=48,d=79 | avg-gen-loss=17.865 | avg-disc-loss=0.908
# My model | epoch=63 | time=06:33:37 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=47,d=78 | avg-gen-loss=18.091 | avg-disc-loss=0.890
# My model | epoch=64 | time=06:33:41 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=46,d=77 | avg-gen-loss=15.448 | avg-disc-loss=1.071
# My model | epoch=65 | time=06:33:45 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=45,d=76 | avg-gen-loss=18.041 | avg-disc-loss=1.338
# My model | epoch=66 | time=06:33:49 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=44,d=75 | avg-gen-loss=16.676 | avg-disc-loss=1.191
# My model | epoch=67 | time=06:33:54 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=43,d=74 | avg-gen-loss=15.464 | avg-disc-loss=1.120
# My model | epoch=68 | time=06:33:58 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=42,d=73 | avg-gen-loss=17.780 | avg-disc-loss=1.055
# My model | epoch=69 | time=06:34:02 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=41,d=72 | avg-gen-loss=16.951 | avg-disc-loss=1.058
# My model | epoch=70 | time=06:34:06 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=40,d=71 | avg-gen-loss=18.560 | avg-disc-loss=0.920
# My model | epoch=71 | time=06:34:18 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=39,d=70 | avg-gen-loss=18.878 | avg-disc-loss=0.797
# My model | epoch=72 | time=06:34:22 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=38,d=100 | avg-gen-loss=21.768 | avg-disc-loss=0.590
# My model | epoch=73 | time=06:34:26 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=37,d=100 | avg-gen-loss=22.809 | avg-disc-loss=0.383
# My model | epoch=74 | time=06:34:30 | speed=0:00:03 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=36,d=100 | avg-gen-loss=22.003 | avg-disc-loss=0.307
# My model | epoch=75 | time=06:34:34 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=35,d=99 | avg-gen-loss=20.061 | avg-disc-loss=0.597
# My model | epoch=76 | time=06:34:39 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=34,d=98 | avg-gen-loss=16.530 | avg-disc-loss=1.465
# My model | epoch=77 | time=06:34:43 | speed=0:00:04 | best avg-gen-loss=15.434 (epoch 60) | overtrain countdown: g=33,d=97 | avg-gen-loss=16.260 | avg-disc-loss=1.640
# My model | epoch=78 | time=06:34:47 | speed=0:00:04 | best avg-gen-loss=15.366 (epoch 78) | overtrain countdown: g=50,d=96 | avg-gen-loss=15.366 | avg-disc-loss=1.262
# My model | epoch=79 | time=06:34:51 | speed=0:00:04 | best avg-gen-loss=15.366 (epoch 78) | overtrain countdown: g=49,d=95 | avg-gen-loss=17.244 | avg-disc-loss=1.075
# My model | epoch=80 | time=06:34:55 | speed=0:00:03 | best avg-gen-loss=15.366 (epoch 78) | overtrain countdown: g=48,d=94 | avg-gen-loss=16.285 | avg-disc-loss=1.015
# My model | epoch=81 | time=06:35:19 | speed=0:00:03 | best avg-gen-loss=14.944 (epoch 81) | overtrain countdown: g=50,d=93 | avg-gen-loss=14.944 | avg-disc-loss=1.042
# My model | epoch=82 | time=06:35:24 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=50,d=92 | avg-gen-loss=14.453 | avg-disc-loss=1.052
# My model | epoch=83 | time=06:35:29 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=49,d=91 | avg-gen-loss=17.697 | avg-disc-loss=1.168
# My model | epoch=84 | time=06:35:33 | speed=0:00:03 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=48,d=90 | avg-gen-loss=15.911 | avg-disc-loss=1.085
# My model | epoch=85 | time=06:35:37 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=47,d=89 | avg-gen-loss=16.122 | avg-disc-loss=1.039
# My model | epoch=86 | time=06:35:41 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=46,d=88 | avg-gen-loss=15.829 | avg-disc-loss=1.285
# My model | epoch=87 | time=06:35:46 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=45,d=87 | avg-gen-loss=18.230 | avg-disc-loss=1.300
# My model | epoch=88 | time=06:35:50 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=44,d=86 | avg-gen-loss=16.607 | avg-disc-loss=1.128
# My model | epoch=89 | time=06:35:54 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=43,d=85 | avg-gen-loss=17.075 | avg-disc-loss=1.030
# My model | epoch=90 | time=06:35:58 | speed=0:00:04 | best avg-gen-loss=14.453 (epoch 82) | overtrain countdown: g=42,d=84 | avg-gen-loss=16.286 | avg-disc-loss=1.055
# My model | epoch=91 | time=06:36:49 | speed=0:00:03 | best avg-gen-loss=14.308 (epoch 91) | overtrain countdown: g=50,d=83 | avg-gen-loss=14.308 | avg-disc-loss=1.025
# My model | epoch=92 | time=06:36:53 | speed=0:00:03 | best avg-gen-loss=14.308 (epoch 91) | overtrain countdown: g=49,d=82 | avg-gen-loss=16.363 | avg-disc-loss=0.942
# My model | epoch=93 | time=06:36:57 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=50,d=81 | avg-gen-loss=14.094 | avg-disc-loss=1.041
# My model | epoch=94 | time=06:37:01 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=49,d=80 | avg-gen-loss=15.253 | avg-disc-loss=1.134
# My model | epoch=95 | time=06:37:05 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=48,d=79 | avg-gen-loss=18.374 | avg-disc-loss=0.933
# My model | epoch=96 | time=06:37:09 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=47,d=78 | avg-gen-loss=19.711 | avg-disc-loss=0.571
# My model | epoch=97 | time=06:37:14 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=46,d=77 | avg-gen-loss=20.709 | avg-disc-loss=0.394
# My model | epoch=98 | time=06:37:18 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=45,d=100 | avg-gen-loss=21.294 | avg-disc-loss=0.241
# My model | epoch=99 | time=06:37:22 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=44,d=100 | avg-gen-loss=21.006 | avg-disc-loss=0.133
# My model | epoch=100 | time=06:37:26 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=43,d=100 | avg-gen-loss=20.882 | avg-disc-loss=0.105
# My model | epoch=101 | time=06:38:10 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=42,d=99 | avg-gen-loss=19.935 | avg-disc-loss=0.254
# My model | epoch=102 | time=06:38:14 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=41,d=98 | avg-gen-loss=17.790 | avg-disc-loss=0.925
# My model | epoch=103 | time=06:38:18 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=40,d=97 | avg-gen-loss=17.488 | avg-disc-loss=2.480
# My model | epoch=104 | time=06:38:22 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=39,d=96 | avg-gen-loss=17.758 | avg-disc-loss=1.952
# My model | epoch=105 | time=06:38:27 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=38,d=95 | avg-gen-loss=16.932 | avg-disc-loss=1.430
# My model | epoch=106 | time=06:38:31 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=37,d=94 | avg-gen-loss=15.870 | avg-disc-loss=1.177
# My model | epoch=107 | time=06:38:35 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=36,d=93 | avg-gen-loss=17.010 | avg-disc-loss=1.140
# My model | epoch=108 | time=06:38:40 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=35,d=92 | avg-gen-loss=16.771 | avg-disc-loss=1.142
# My model | epoch=109 | time=06:38:44 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=34,d=91 | avg-gen-loss=14.848 | avg-disc-loss=1.072
# My model | epoch=110 | time=06:38:48 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=33,d=90 | avg-gen-loss=18.407 | avg-disc-loss=0.839
# My model | epoch=111 | time=06:39:13 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=32,d=89 | avg-gen-loss=17.678 | avg-disc-loss=0.875
# My model | epoch=112 | time=06:39:16 | speed=0:00:03 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=31,d=88 | avg-gen-loss=15.808 | avg-disc-loss=1.099
# My model | epoch=113 | time=06:39:21 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=30,d=87 | avg-gen-loss=17.463 | avg-disc-loss=1.131
# My model | epoch=114 | time=06:39:25 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=29,d=86 | avg-gen-loss=15.882 | avg-disc-loss=1.113
# My model | epoch=115 | time=06:39:29 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=28,d=85 | avg-gen-loss=14.507 | avg-disc-loss=1.098
# My model | epoch=116 | time=06:39:33 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=27,d=84 | avg-gen-loss=17.113 | avg-disc-loss=0.942
# My model | epoch=117 | time=06:39:37 | speed=0:00:04 | best avg-gen-loss=14.094 (epoch 93) | overtrain countdown: g=26,d=83 | avg-gen-loss=14.402 | avg-disc-loss=1.027
# My model | epoch=118 | time=06:39:41 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=50,d=82 | avg-gen-loss=12.942 | avg-disc-loss=1.144
# My model | epoch=119 | time=06:39:46 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=49,d=81 | avg-gen-loss=16.929 | avg-disc-loss=1.137
# My model | epoch=120 | time=06:39:50 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=48,d=80 | avg-gen-loss=17.437 | avg-disc-loss=1.059
# My model | epoch=121 | time=06:40:31 | speed=0:00:03 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=47,d=79 | avg-gen-loss=16.365 | avg-disc-loss=0.927
# My model | epoch=122 | time=06:40:34 | speed=0:00:03 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=46,d=78 | avg-gen-loss=19.423 | avg-disc-loss=0.812
# My model | epoch=123 | time=06:40:38 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=45,d=77 | avg-gen-loss=17.525 | avg-disc-loss=0.777
# My model | epoch=124 | time=06:40:43 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=44,d=76 | avg-gen-loss=16.189 | avg-disc-loss=0.831
# My model | epoch=125 | time=06:40:47 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=43,d=75 | avg-gen-loss=14.114 | avg-disc-loss=0.999
# My model | epoch=126 | time=06:40:51 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=42,d=74 | avg-gen-loss=15.168 | avg-disc-loss=1.117
# My model | epoch=127 | time=06:40:55 | speed=0:00:04 | best avg-gen-loss=12.942 (epoch 118) | overtrain countdown: g=41,d=73 | avg-gen-loss=14.259 | avg-disc-loss=1.177
# My model | epoch=128 | time=06:40:59 | speed=0:00:04 | best avg-gen-loss=12.619 (epoch 128) | overtrain countdown: g=50,d=72 | avg-gen-loss=12.619 | avg-disc-loss=1.119
# My model | epoch=129 | time=06:41:04 | speed=0:00:04 | best avg-gen-loss=12.619 (epoch 128) | overtrain countdown: g=49,d=71 | avg-gen-loss=14.832 | avg-disc-loss=1.013
# My model | epoch=130 | time=06:41:08 | speed=0:00:04 | best avg-gen-loss=12.619 (epoch 128) | overtrain countdown: g=48,d=70 | avg-gen-loss=13.129 | avg-disc-loss=1.076
# My model | epoch=131 | time=06:41:44 | speed=0:00:03 | best avg-gen-loss=12.619 (epoch 128) | overtrain countdown: g=47,d=69 | avg-gen-loss=14.126 | avg-disc-loss=1.116
# My model | epoch=132 | time=06:41:48 | speed=0:00:03 | best avg-gen-loss=12.619 (epoch 128) | overtrain countdown: g=46,d=68 | avg-gen-loss=13.141 | avg-disc-loss=1.060
# My model | epoch=133 | time=06:41:52 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=50,d=67 | avg-gen-loss=12.306 | avg-disc-loss=1.102
# My model | epoch=134 | time=06:41:56 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=49,d=66 | avg-gen-loss=15.495 | avg-disc-loss=1.072
# My model | epoch=135 | time=06:42:01 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=48,d=65 | avg-gen-loss=14.058 | avg-disc-loss=1.099
# My model | epoch=136 | time=06:42:05 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=47,d=64 | avg-gen-loss=13.870 | avg-disc-loss=1.021
# My model | epoch=137 | time=06:42:09 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=46,d=63 | avg-gen-loss=12.915 | avg-disc-loss=1.056
# My model | epoch=138 | time=06:42:13 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=45,d=62 | avg-gen-loss=16.339 | avg-disc-loss=1.093
# My model | epoch=139 | time=06:42:18 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=44,d=61 | avg-gen-loss=14.988 | avg-disc-loss=1.075
# My model | epoch=140 | time=06:42:22 | speed=0:00:04 | best avg-gen-loss=12.306 (epoch 133) | overtrain countdown: g=43,d=60 | avg-gen-loss=17.244 | avg-disc-loss=0.866
